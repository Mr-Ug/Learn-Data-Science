# %%
# Persiapan membuat data
import pandas as pd
import random

pelajaran = ['Matematika', 'Fisika', 'Biologi', 'Kimia', 'Geologi', 'Ekonomi']
kelas = ['12A', '12B', '12C', '12D']

hasil_nilai = {
    'siswa_id' : range(1, 21),
    'pelajaran' : [random.choice(pelajaran) for i in range(20)],
    'nilai' : [random.choice(range(0, 100)) for i in range(20)],
    'jenis_kelamin' : [random.choice(['laki-laki', 'perempuan']) for i in range(20)],
    'kelas' : [random.choice(kelas) for i in range(20)]
}

df = pd.DataFrame(hasil_nilai)
df.head()
# Out:
#    siswa_id   pelajaran  nilai jenis_kelamin kelas
# 0         1  Matematika     46     perempuan   12D
# 1         2  Matematika     63     laki-laki   12B
# 2         3     Ekonomi     63     perempuan   12C
# 3         4      Fisika     88     perempuan   12A
# 4         5     Ekonomi      1     perempuan   12C

# %% [markdown]
# <h2>Soal 1: Indexing</h2>
#
# 1. Lakukan indexing terhadap dataframe untuk mengakses column nilai dan kelas saja
# 2. Lakukan indexing terhadap dataframe untuk mengakses row 5 sampai 10 beserta column pelajaran dan nilai

# %%
# code here
# dataFrame["label","label","...","etc"]
Indexing_nilai_dan_kelas = df[["nilai","kelas"]]
Indexing_nilai_dan_kelas
# Out:
#     nilai kelas
# 0      46   12D
# 1      63   12B
# 2      63   12C
# 3      88   12A
# 4       1   12C
# 5      19   12C
# 6      10   12C
# 7      13   12B
# 8      74   12D
# 9      88   12D
# 10     96   12A
# 11     67   12C
# 12      5   12D
# 13     93   12B
# 14     32   12B
# 15     28   12A
# 16     86   12C
# 17     68   12B
# 18     55   12C
# 19     91   12B

# %%
# dataFrame.loc[index:index, ["label","label","...","etc"]]
# Cara 1

Cara1 = df.loc[4:9, ["pelajaran","nilai"]]
display(Cara1)
# Cara 2
Cara2 = df.iloc[4:10,[1,2]]
display(Cara2)
# Out:
#      pelajaran  nilai
# 5   Matematika     19
# 6      Ekonomi     10
# 7      Biologi     13
# 8      Geologi     74
# 9       Fisika     88
# 10      Fisika     96
#     pelajaran  nilai
# 4     Ekonomi      1
# 5  Matematika     19
# 6     Ekonomi     10
# 7     Biologi     13
# 8     Geologi     74
# 9      Fisika     88

# %% [markdown]
# <h2>Soal 2: Filter DataFrame Dengan Boolean</h2>
#
# 1. Tampilkan semua data siswa pada mata pelajaran Ekonomi dan Fisika
# 2. Tampilkan semua data siswa yang mempunyai nilai lebih dari 50 di mata pelajaran Kimia
# 3. Tampilkan semua data yang mempunyai nilai lebih dari 70, berjnis kelamin perempuan dan di kelas 12C

# %%
# code here
# 1. Tampilkan semua data siswa pada mata pelajaran Ekonomi dan Fisika
# | = or & = and
df[(df["pelajaran"] == "Ekonomi") | (df["pelajaran"] == "Fisika")]
# Out:
#     siswa_id pelajaran  nilai jenis_kelamin kelas
# 0          1   Ekonomi      3     perempuan   12B
# 2          3    Fisika      4     laki-laki   12B
# 3          4   Ekonomi     14     laki-laki   12D
# 9         10    Fisika     42     perempuan   12C
# 14        15    Fisika     40     perempuan   12C
# 16        17    Fisika     97     laki-laki   12B
# 17        18   Ekonomi     39     laki-laki   12B
# 18        19   Ekonomi     20     laki-laki   12B

# %%
# 2. Tampilkan semua data siswa yang memiliki nilai lebih dari 50 di mata pelajaran Kimia
mata_pelajaran_kimia = df.pelajaran == "Kimia"
lebih_50 = df.nilai > 50
df[(mata_pelajaran_kimia) & (lebih_50)]
#
# Out:
#     siswa_id pelajaran  nilai jenis_kelamin kelas
# 1          2     Kimia     72     laki-laki   12D
# 13        14     Kimia     93     perempuan   12A

# %% [markdown]
# Analisis soal 2.2
# - Dari data yang didapat di kelas 12B terdapat siswi yang memiliki nilai kimia dengan nilai 77

# %%
#3. Tampilkan semua data yang mempunyai nilai lebih dari 70, Jenis Kelamin Perempuan, Kelas 12C
nilai_70 = df.nilai > 70
jenis_kelamin = df.jenis_kelamin == "perempuan"
kelas_12C = df.kelas =="12C"

df[(nilai_70) & (jenis_kelamin) & (kelas_12C)]
#
# Out:
#     siswa_id   pelajaran  nilai jenis_kelamin kelas
# 5          6  Matematika     81     perempuan   12C
# 13        14     Biologi     79     perempuan   12C

# %% [markdown]
# Analisis Soal 2.3
# - Dari data yang didapat, terdapat 2 siswi di kelas 12C yang memiliki nilai pelajaran matematika dan Biologi dengan nilai diatas 70

# %% [markdown]
# <h2>Soal 3: Data Transformation</h2>
#
# lakukan data transformasi terhadap column 'nilai' dengan fungsi transformasi, berikut rumus dari normalisasi
#
# ![alt text](https://drive.google.com/uc?id=1wed-EbRSTA0JP1ceDp6lcKBqH2yJ4aa3)

# %%
# code here
def normalize(x):
    return x - x.min()/(x.max()-x.min())
df[["nilai"]].apply(normalize)
# Out:
#        nilai
# 0   34.82716
# 1   32.82716
# 2   86.82716
# 3   13.82716
# 4   49.82716
# 5   29.82716
# 6   58.82716
# 7   60.82716
# 8   13.82716
# 9   85.82716
# 10  22.82716
# 11  18.82716
# 12  94.82716
# 13  19.82716
# 14  90.82716
# 15  51.82716
# 16  27.82716
# 17  78.82716
# 18  31.82716
# 19  24.82716
